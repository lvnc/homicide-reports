# %% [markdown]
# # Homicide Reports USA

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from zipfile import ZipFile

pd.__version__
# Out:
# '0.24.2'

# %%
zip = ZipFile('homicide-reports.zip')
zip.extractall()

# %%
database = pd.read_csv('database.csv')

# %%
database.columns
# Out:
# Index(['Record ID', 'Agency Code', 'Agency Name', 'Agency Type', 'City',
#        'State', 'Year', 'Month', 'Incident', 'Crime Type', 'Crime Solved',
#        'Victim Sex', 'Victim Age', 'Victim Race', 'Victim Ethnicity',
#        'Perpetrator Sex', 'Perpetrator Age', 'Perpetrator Race',
#        'Perpetrator Ethnicity', 'Relationship', 'Weapon', 'Victim Count',
#        'Perpetrator Count', 'Record Source'],
#       dtype='object')

# %%
database.head()
# Out:
#    Record ID Agency Code Agency Name       Agency Type       City   State  \
# 0          1     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 1          2     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 2          3     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 3          4     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
# 4          5     AK00101   Anchorage  Municipal Police  Anchorage  Alaska
#
#    Year    Month  Incident              Crime Type  ... Victim Ethnicity  \
# 0  1980  January         1  Murder or Manslaughter  ...          Unknown
# 1  1980    March         1  Murder or Manslaughter  ...          Unknown
# 2  1980    March         2  Murder or Manslaughter  ...          Unknown
# 3  1980    April         1  Murder or Manslaughter  ...          Unknown
# 4  1980    April         2  Murder or Manslaughter  ...          Unknown
#
#   Perpetrator Sex  Perpetrator Age               Perpetrator Race  \
# ...

# %%
sex = database['Victim Sex'].value_counts()

# %%
sex
# Out:
# Male       494125
# Female     143345
# Unknown       984
# Name: Victim Sex, dtype: int64

# %%
pd.crosstab(database['Perpetrator Sex'], database['Victim Sex'])
# Out:
# Victim Sex       Female    Male  Unknown
# Perpetrator Sex
# Female            10869   37629       50
# Male              99381  299879      281
# Unknown           33095  156617      653

# %%
relationship = database['Relationship'].value_counts()

# %%
relationship
# Out:
# Unknown                 273013
# Acquaintance            126018
# Stranger                 96593
# Wife                     23187
# Friend                   21945
# Girlfriend               16465
# Son                       9904
# Family                    9535
# Husband                   8803
# Daughter                  7539
# Boyfriend                 7302
# Neighbor                  6294
# Brother                   5514
# Father                    4361
# Mother                    4248
# In-Law                    3637
# Common-Law Wife           2477
# Ex-Wife                   1973
# Common-Law Husband        1954
# Boyfriend/Girlfriend      1383
# Stepfather                1360
# Sister                    1292
# Stepson                   1170
# Stepdaughter               754
# Ex-Husband                 629
# Employer                   509
# Employee                   384
# Stepmother                 211
# Name: Relationship, dtype: int64

# %%
plt.figure(figsize=(6, 10))

sns.heatmap(pd.crosstab(database['Relationship'], database['Perpetrator Sex']), 
            linewidth = .1, annot=True, fmt= '.0f', cmap= "RdPu")

plt.title("Relationship x Perpetrator Sex", 
          fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Relationship x Perpetrator Sex')

# %%
plt.figure(figsize=(6, 6))

sns.heatmap(pd.crosstab(database['Weapon'], database['Perpetrator Sex']), 
            linewidth = .1, annot=True, fmt= '.0f', cmap= "RdPu")

plt.title("Weapon x Perpetrator Sex",
          fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Weapon x Perpetrator Sex')

# %% [markdown]
# ## Women

# %%
women = []

for row in database.index:
    if database['Perpetrator Sex'][row] == 'Female':
        women.append(row)
    
df_women = database.loc[women, :]

# %%
df_women['Relationship'].value_counts()
# Out:
# Acquaintance            8726
# Husband                 8614
# Boyfriend               7043
# Unknown                 4995
# Son                     3859
# Daughter                3603
# Stranger                2812
# Common-Law Husband      1891
# Friend                  1683
# Family                  1260
# Mother                   687
# Ex-Husband               589
# Neighbor                 484
# Brother                  480
# Father                   473
# In-Law                   294
# Sister                   251
# Boyfriend/Girlfriend     196
# Stepfather               181
# Girlfriend                98
# Wife                      85
# Stepson                   68
# Stepdaughter              61
# Employer                  33
# Employee                  33
# Stepmother                25
# Common-Law Wife           19
# Ex-Wife                    5
# Name: Relationship, dtype: int64

# %%
plt.figure(figsize=(20, 20))

sns.heatmap(pd.crosstab(df_women['Relationship'], df_women['Weapon']), 
            linewidth = .4, annot=True, fmt= '.0f', cmap= "RdPu")

plt.title("Women: Relationship x Weapon", 
          fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Women: Relationship x Weapon')

# %% [markdown]
# ## Men

# %%
men = []

for row in database.index:
    if database['Perpetrator Sex'][row] == 'Male':
        men.append(row)
    
df_men = database.loc[men, :]

# %%
df_men['Relationship'].value_counts()
# Out:
# Acquaintance            115126
# Unknown                  89812
# Stranger                 84550
# Wife                     23058
# Friend                   20035
# Girlfriend               16315
# Family                    8207
# Son                       5983
# Neighbor                  5774
# Brother                   5016
# Daughter                  3884
# Father                    3880
# Mother                    3551
# In-Law                    3334
# Common-Law Wife           2451
# Ex-Wife                   1961
# Stepfather                1177
# Stepson                   1101
# Boyfriend/Girlfriend      1085
# Sister                    1037
# Stepdaughter               693
# Employer                   476
# Employee                   347
# Boyfriend                  245
# Stepmother                 186
# Husband                    164
# Common-Law Husband          56
# Ex-Husband                  37
# Name: Relationship, dtype: int64

# %%
plt.figure(figsize=(20, 20))

sns.heatmap(pd.crosstab(df_men['Relationship'], df_men['Weapon']), 
            linewidth = .4, annot=True, fmt= '.1f', cmap= "RdPu")

plt.title("Men: Relationship x Weapon", 
          fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Men: Relationship x Weapon')
